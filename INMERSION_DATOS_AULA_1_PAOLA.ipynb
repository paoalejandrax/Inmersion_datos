# %% [markdown]
# <a href="https://colab.research.google.com/github/paoalejandrax/Inmersion_datos/blob/main/INMERSION_DATOS_AULA_1_PAOLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Desafios de Aula

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
inmuebles = pd.read_csv('/content/drive/MyDrive/Inmersion_datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columns = {'Baños': 'Banos', 'Área': 'Area'}
inmuebles = inmuebles.rename(columns=columns)
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7573  Apartamento         Apartamento en venta en Santa Paula             2
# 817   Apartamento  Apartamento en venta en Zona Noroccidental             2
# 9347  Apartamento            Apartamento en venta en Cedritos             3
# 8816  Apartamento  Apartamento en venta en Portales Del Norte             3
# 4907         Casa                    Casa en venta en Kennedy             9
# 2274  Apartamento      Apartamento en venta en Barrios Unidos             1
# 8336  Apartamento       Apartamento en venta en Puente Aranda             3
# 1414  Apartamento             Apartamento en venta en El Plan             3
# 1647  Apartamento            Apartamento en venta en Engativa             3
# 7798         Casa                    Casa en venta en Palermo             5
#
#       Banos  Area              Barrio  \
# 7573      2    64         Santa Paula
# 817       1    41  Zona Noroccidental
# ...

# %%
inmuebles.iloc[200]
# Out:
# Tipo                                    Apartamento
# Descripcion     Apartamento en venta en El Contador
# Habitaciones                                      3
# Banos                                             3
# Area                                             90
# Barrio                                  El Contador
# UPZ                                      Los Cedros
# Valor                                 $ 460.000.000
# Name: 200, dtype: object

# %%
inmuebles.iloc[200:205]
# Out:
#             Tipo                                 Descripcion  Habitaciones  \
# 200  Apartamento         Apartamento en venta en El Contador             3
# 201  Apartamento            Apartamento en venta en Cedritos             2
# 202  Apartamento  Apartamento en venta en Rafael Uribe Uribe             3
# 203  Apartamento  Apartamento en venta en Zona Noroccidental             2
# 204  Apartamento  Apartamento en venta en Zona Noroccidental             4
#
#      Banos  Area              Barrio                                 UPZ  \
# 200      3    90         El Contador                          Los Cedros
# 201      1    52            Cedritos                             Usaquén
# 202      2    58  Rafael Uribe Uribe                       Los Alcázares
# 203      2    50  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 204      2    73  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
#
#              Valor
# 200  $ 460.000.000
# 201  $ 225.000.000
# ...

# %%
inmuebles.head(11)
# Out:
#            Tipo                                 Descripcion  Habitaciones  \
# 0   Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1          Casa                   Casa en venta en Castilla             4
# 2   Apartamento     Apartamento en venta en Chico Reservado             3
# 3   Apartamento             Apartamento en venta en Usaquén             3
# 4   Apartamento         Apartamento en venta en Bella Suiza             2
# 5   Apartamento         Apartamento en venta en Bella Suiza             1
# 6   Apartamento         Apartamento en venta en Bella Suiza             1
# 7   Apartamento         Apartamento en venta en Bella Suiza             3
# 8   Apartamento            Apartamento en venta en El Chicó             3
# 9   Apartamento         Apartamento en venta en Bella Suiza             2
# 10  Apartamento         Apartamento en venta en Bella Suiza             2
#
#     Banos  Area              Barrio                                    UPZ  \
# ...

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >
